# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import os

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
expend_file_path = os.path.join("Data", "healthexpend.csv")

# %%
expend_df = pd.read_csv(expend_file_path)
expend_df
# Out:
#     Per.capita.government.expenditure.on.health.at.average.exchange.rate..US..  \
# 0                                             Abkhazia
# 1                                          Afghanistan
# 2                                Akrotiri and Dhekelia
# 3                                              Albania
# 4                                              Algeria
# ..                                                 ...
# 260                                          Christian
# 261                                          Coastline
# 262                                            Curaçao
# 263                          Sint Maarten (Dutch part)
# 264                           St. Martin (French part)
#
#           1995       1996       1997       1998       1999       2000  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3    13.940591  17.062074  14.164771  18.625848  28.139706  27.160512
# 4    46.771460  47.960053  49.738400  48.670547  45.543825  45.911115
# ..         ...        ...        ...        ...        ...        ...
# 260        NaN        NaN        NaN        NaN        NaN        NaN
# 261        NaN        NaN        NaN        NaN        NaN        NaN
# 262        NaN        NaN        NaN        NaN        NaN        NaN
# 263        NaN        NaN        NaN        NaN        NaN        NaN
# 264        NaN        NaN        NaN        NaN        NaN        NaN
#
#           2001       2002       2003       2004       2005       2006  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN   0.832643   1.250118   1.614160   2.525066   2.813779
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3    30.509619  32.549902  40.609457  63.935601  71.356600  75.552514
# 4    52.509423  54.078381  62.637209  63.229395  69.295636  81.679706
# ..         ...        ...        ...        ...        ...        ...
# 260        NaN        NaN        NaN        NaN        NaN        NaN
# 261        NaN        NaN        NaN        NaN        NaN        NaN
# 262        NaN        NaN        NaN        NaN        NaN        NaN
# 263        NaN        NaN        NaN        NaN        NaN        NaN
# 264        NaN        NaN        NaN        NaN        NaN        NaN
#
#            2007        2008        2009        2010
# 0           NaN         NaN         NaN         NaN
# 1      3.503426    3.744613    3.908887    4.390408
# 2           NaN         NaN         NaN         NaN
# 3     88.762634  109.074284  106.893745   94.023613
# 4    108.904747  147.820707  143.160577  138.840923
# ..          ...         ...         ...         ...
# 260         NaN         NaN         NaN         NaN
# 261         NaN         NaN         NaN         NaN
# 262         NaN         NaN         NaN         NaN
# 263         NaN         NaN         NaN         NaN
# 264         NaN         NaN         NaN         NaN
#
# [265 rows x 17 columns]

# %%
expend_df_clean = expend_df.melt(['Per.capita.government.expenditure.on.health.at.average.exchange.rate..US..'], var_name='Year', value_name='Value')
expend_df_clean
# Out:
#      Per.capita.government.expenditure.on.health.at.average.exchange.rate..US..  \
# 0                                              Abkhazia
# 1                                           Afghanistan
# 2                                 Akrotiri and Dhekelia
# 3                                               Albania
# 4                                               Algeria
# ...                                                 ...
# 4235                                          Christian
# 4236                                          Coastline
# 4237                                            Curaçao
# 4238                          Sint Maarten (Dutch part)
# 4239                           St. Martin (French part)
#
#       Year      Value
# 0     1995        NaN
# 1     1995        NaN
# 2     1995        NaN
# 3     1995  13.940591
# 4     1995  46.771460
# ...    ...        ...
# 4235  2010        NaN
# 4236  2010        NaN
# 4237  2010        NaN
# 4238  2010        NaN
# 4239  2010        NaN
#
# [4240 rows x 3 columns]

# %%
# Out:
#                                                     Year      Value
# Per.capita.government.expenditure.on.health.at....
# Abkhazia                                            1995        NaN
# Afghanistan                                         1995        NaN
# Akrotiri and Dhekelia                               1995        NaN
# Albania                                             1995  13.940591
# Algeria                                             1995  46.771460
# ...                                                  ...        ...
# Christian                                           2010        NaN
# Coastline                                           2010        NaN
# Curaçao                                             2010        NaN
# Sint Maarten (Dutch part)                           2010        NaN
# St. Martin (French part)                            2010        NaN
#
# [4240 rows x 2 columns]

# %%
expend_df_clean = expend_df_clean.replace(np.nan, '', regex=True)

# %%
expend_df_clean
# Out:
#      Per.capita.government.expenditure.on.health.at.average.exchange.rate..US..  \
# 0                                              Abkhazia
# 1                                           Afghanistan
# 2                                 Akrotiri and Dhekelia
# 3                                               Albania
# 4                                               Algeria
# ...                                                 ...
# 4235                                          Christian
# 4236                                          Coastline
# 4237                                            Curaçao
# 4238                          Sint Maarten (Dutch part)
# 4239                           St. Martin (French part)
#
#       Year    Value
# 0     1995
# 1     1995
# 2     1995
# 3     1995  13.9406
# 4     1995  46.7715
# ...    ...      ...
# 4235  2010
# 4236  2010
# 4237  2010
# 4238  2010
# 4239  2010
#
# [4240 rows x 3 columns]

# %%
expend_df_clean2.to_csv("health_expend_cleaned.csv", encoding='utf-8', index=False)

# %% [markdown]
# ### Transform premise DataFrame

# %% [markdown]
# ### Transform county DataFrame

# %% [markdown]
# ### Create database connection

# %%
# Confirm tables

# %% [markdown]
# ### Load DataFrames into database
