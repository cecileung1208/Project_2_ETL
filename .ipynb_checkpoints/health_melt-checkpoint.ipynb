# %%
import os
import pandas as pd

# %%
file_path_health = os.path.join("Data", "healthexpend.csv")

# %%
health_data = pd.read_csv(file_path_health)
health_data
# Out:
#      country_ID        1995        1996        1997         1998        1999  \
# 0             1         NaN         NaN         NaN          NaN         NaN
# 1             2   13.940591   17.062074   14.164771    18.625848   28.139706
# 2             3   46.771460   47.960053   49.738400    48.670547   45.543825
# 3             4  897.181541  982.794819  966.484960  1338.295221  942.421563
# 4             5   13.516833    8.724155   10.527305     6.648744    6.548254
# ..          ...         ...         ...         ...          ...         ...
# 187         192   61.227961   45.010830   51.832277    57.118210   85.775764
# 188         193    4.925340    5.357862    5.659303     6.116791    6.323162
# 189         194   12.421901   10.966882    9.437519    10.129011   10.849342
# 190         195   13.237821   13.041775   16.831740    13.570401    9.018808
# 191         196   28.052004   29.347400   30.080158    29.437772   17.635314
#
# ...

# %%
health_data_melt =health_data.melt(['country_ID'], var_name='year', value_name='value')
health_data_melt
# Out:
#       country_ID  year       value
# 0              1  1995         NaN
# 1              2  1995   13.940591
# 2              3  1995   46.771460
# 3              4  1995  897.181541
# 4              5  1995   13.516833
# ...          ...   ...         ...
# 3067         192  2010  231.518602
# 3068         193  2010   31.359855
# 3069         194  2010   15.269640
# 3070         195  2010   43.932037
# 3071         196  2010         NaN
#
# [3072 rows x 3 columns]

# %%
health_data_melt = health_data_melt.fillna('')
health_data_melt
# Out:
#       country_ID  year    value
# 0              1  1995
# 1              2  1995  13.9406
# 2              3  1995  46.7715
# 3              4  1995  897.182
# 4              5  1995  13.5168
# ...          ...   ...      ...
# 3067         192  2010  231.519
# 3068         193  2010  31.3599
# 3069         194  2010  15.2696
# 3070         195  2010   43.932
# 3071         196  2010
#
# [3072 rows x 3 columns]

# %%
health_data_melt.to_csv('health_data_melt.csv')
