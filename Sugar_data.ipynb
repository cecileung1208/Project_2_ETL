# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
file_path_sugar = os.path.join("Data", "sugar_per_person_g_per_day-FAO.csv")

# %%
sugar_data = pd.read_csv(file_path_sugar)
sugar_data
# Out:
#      country_id    1993    1994    1995    1996    1997    1998   1999  \
# 0             1    9.12    8.22    8.45    7.24    7.85    8.34    8.9
# 1             2   76.10   97.50   54.40   63.00   61.70   57.00   56.5
# 2             3   74.30   71.20   70.60   71.90   76.30   52.40   58.9
# 3             5   25.30   20.80   23.50   26.10   31.70   29.10   34.9
# 4             6   82.20   86.70   89.30   88.10   85.90   89.40   87.5
# ..          ...     ...     ...     ...     ...     ...     ...    ...
# 163         192  105.00  108.00  109.00  110.00  105.00  103.00  101.0
# 164         193   16.60   21.40   23.70   23.40   25.00   25.30   30.3
# 165         194   56.40   56.20   55.10   63.20   65.70   65.50   63.4
# 166         195   44.50   40.60   41.00   35.10   40.40   31.40   31.0
# 167         196   56.40   56.60   61.60   64.70   73.50   73.60   74.6
#
#        2000   2001  ...   2004   2005   2006   2007   2008   2009   2010  \
# ...

# %%
sugar_data_melt =sugar_data.melt(['country_id'], var_name='year', value_name='value')
sugar_data_melt
# Out:
#       country_id  year   value
# 0              1  1993    9.12
# 1              2  1993   76.10
# 2              3  1993   74.30
# 3              5  1993   25.30
# 4              6  1993   82.20
# ...          ...   ...     ...
# 3523         192  2013  106.00
# 3524         193  2013   27.40
# 3525         194  2013   77.90
# 3526         195  2013   28.10
# 3527         196  2013   80.60
#
# [3528 rows x 3 columns]

# %%
sugar_data_melt = sugar_data_melt.set_index(['country_id'])
sugar_data_melt
# Out:
#             year   value
# country_id
# 1           1993    9.12
# 2           1993   76.10
# 3           1993   74.30
# 5           1993   25.30
# 6           1993   82.20
# ...          ...     ...
# 192         2013  106.00
# 193         2013   27.40
# 194         2013   77.90
# 195         2013   28.10
# 196         2013   80.60
#
# [3528 rows x 2 columns]

# %%
#saving it into new file
sugar_data_melt.to_csv('sugar_data.csv')

# %% [markdown]
# ### Transform premise DataFrame

# %% [markdown]
# ### Transform county DataFrame

# %% [markdown]
# ### Create database connection

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine(f'postgres://gnhyfpvj:EBKTvM_wJPKtlmLIfcSPytJEJH9_hv_h@raja.db.elephantsql.com:5432/gnhyfpvj')
connection = engine.connect()
print("Connected!")
# Out:
# Connected!

# %%
# Confirm tables
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['country', 'health_expenditures', 'sugar_consumption', 'obesity', 'income']

# %% [markdown]
# ### Load DataFrames into database
