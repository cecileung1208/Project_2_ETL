# %%
import pandas as pd
import os

# %%
file_path_income = os.path.join("Data", "Income by Country.csv")

# %%
income_data = pd.read_csv(file_path_income)
income_data
# Out:
#          Country   1990   1991   1992   1993   1994   1995   1996   1997  \
# 0    Afghanistan   2193   1841   1739   1208    877   1244   1130   1039
# 1        Albania   4415   3138   2857   3261   3600   4168   4594   4112
# 2        Algeria   9989   9457   9462   9171   8847   8904   9069   9099
# 3        Andorra  49062  48391  47002  44928  44747  45136  46861  51136
# 4         Angola   4139   4528   1737   1704   1304   2858   2826   3335
# ..           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 185    Venezuela  14529  15667  15945  15666  14919  15290  14943  15524
# 186      Vietnam   1369   1436   1559   1645   1781   1944   2084   2217
# 187        Yemen   2382   2423   2258   2237   2112   1796   2364   2760
# 188       Zambia   2140   2020   1969   2101   1900   1909   1988   2006
# 189     Zimbabwe   2693   2764   2448   2440   2611   2574   2833   2851
#
#       1998  ...   2009   2010   2011   2012   2013   2014   2015   2016  \
# ...

# %%
income_melt = income_data.melt(['Country'], var_name='Year', value_name='Value')
income_melt.head()
# Out:
#        Country  Year  Value
# 0  Afghanistan  1990   2193
# 1      Albania  1990   4415
# 2      Algeria  1990   9989
# 3      Andorra  1990  49062
# 4       Angola  1990   4139
